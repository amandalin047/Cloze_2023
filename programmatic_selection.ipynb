# %%
import pandas as pd
import numpy as np
import os

def REINDEX(array):
    '''Sorts sentences by a given index in asencing order'''
    array_ascend = np.sort(array)
    unique, idx = [], []
    for i, x in enumerate(array_ascend):
        if x not in unique:
            idx.append(np.where(array==x)[0].tolist())
            unique.append(x)
    return sum(idx, [])

def main(df, exp_thresh=4.5, plaus_thresh=5, val_thresh=2, condition=None, drop=True):
    '''exp_thresh: To drop those zero-cloze unexpected sentences rated as highly expected. If set to, for instance, 5.75,
       then those zero-cloze sentences with rated expectancy >= 5.75 will be dropped. If set to 8, no such dropping will happen
       as expectancy was rated on a scale of 1 to 7.
       
       plaus_thresh: To drop sentences with plausibility <= plaus_thresh.
       
       val_thresh: If condition="Emo", then sentences with absolute valence <= val_thresh will be dropped
                   If condition="Neu", then sentences with absolute valence >= val_thesh will be dropped. '''
    df = df.reindex(REINDEX(df['Cloze'])).reset_index(drop=True);
    
    num_zero_cloze = len([i for i in df['Cloze'].tolist() if i==0])
    new_df = pd.DataFrame(None, columns=df.columns)
    for i in range(len(df.head(num_zero_cloze))):
        if df['Exp. mean'].iloc[i] <= exp_thresh: new_df.loc[len(new_df)] = df.iloc[i]     

    for i in range(len(df.head(num_zero_cloze)),len(df)):
        if df['Index'].iloc[i] in new_df['Index'].tolist(): new_df.loc[len(new_df)] = df.iloc[i]
    
    new_df = new_df.reindex(REINDEX(new_df['Index'])).reset_index(drop=True)
    
    new_df = new_df[new_df['Plaus. mean']>=plaus_thresh]
    if condition == 'Emo':
        new_df = new_df[(new_df['Val. mean']>=5+val_thresh) | (new_df['Val. mean']<=5-val_thresh)].reset_index(drop=True)
    elif condition == 'Neu':
        new_df = new_df[(new_df['Val. mean']<=5+val_thresh) & (new_df['Val. mean']>=5-val_thresh)].reset_index(drop=True)
    new_df = new_df.reindex(REINDEX(new_df['Index'])).reset_index(drop=True)
    
    # drops sentences that do not have a counterpart
    if drop == True:
        idx = new_df['Index'].tolist()
        for i, x in enumerate(idx):
            if idx.count(x) == 1:
                new_df = new_df.drop(index=i)
                
    if drop == True:
        sc, wc = new_df[(new_df['Index']%4==0) | (new_df['Index']%4==1)], new_df[(new_df['Index']%4==2) | (new_df['Index']%4==3)]
        print('number of '+condition+'_SC frames =', int(len(new_df[(new_df['Index']%4==0) | (new_df['Index']%4==1)])/2))
        display(new_df[(new_df['Index']%4==0) | (new_df['Index']%4==1)])
        print('\n')
        print('number of '+condition+'_WC frames =', int(len(new_df[(new_df['Index']%4==2) | (new_df['Index']%4==3)])/2))
        display(new_df[(new_df['Index']%4==2) | (new_df['Index']%4==3)])
        print('\n')
    else:
        sc, wc = new_df[(new_df['Index']%4==0) | (new_df['Index']%4==1)], new_df[(new_df['Index']%4==2) | (new_df['Index']%4==3)]
        print('number of '+condition+'_SC sentences =', len(new_df[(new_df['Index']%4==0) | (new_df['Index']%4==1)]))
        display(new_df[(new_df['Index']%4==0) | (new_df['Index']%4==1)])
        print('\n')
        print('number of '+condition+'_WC sentences =', len(new_df[(new_df['Index']%4==2) | (new_df['Index']%4==3)]))
        display(new_df[(new_df['Index']%4==2) | (new_df['Index']%4==3)])
        print('\n')
        
    
    return sc, wc

# %%
# If we don't drop singled out sentences
os.chdir('/home/amandalin047/july_ratings/results/1st_round')
df = pd.read_excel('1st_all_means.xlsx')

emo_sc, emo_wc = main(df, exp_thresh=8, plaus_thresh=4.5, val_thresh=1.8, condition='Emo', drop=False);
neu_sc, neu_wc = main(df, exp_thresh=8, plaus_thresh=4.5, val_thresh=0.9, condition='Neu', drop=False);
# Out:
# number of Emo_SC sentences = 48
#    Index                    Sentences     Cloze Exp. mean Plaus. mean  \
# 3     12    你這樣花光家產完全不知孝順，別到父母都掛了才後悔。  0.866667  5.733333         5.8
# 8     28    他痛苦到鐵了心要自殺並留下絕筆，便於今晨寫下遺書。  0.933333       5.6    6.133333
# 9     32      不滿官員暴利欺壓，憤怒的鄉民聚集凱道大聲喊話。       0.0  4.533333         5.2
# 10    32      不滿官員暴利欺壓，憤怒的鄉民聚集凱道大聲抗議。  0.888889  6.266667         6.4
# 13    44      他車禍重傷血肉模糊狀況淒慘，搶救的希望全沒了。       0.0       5.2         5.4
# 14    44       他車禍重傷血肉模糊狀況淒慘，搶救的希望渺茫。  0.866667  5.666667         6.2
# 16    56      聽到女兒被綁架犯毆打的聲音，小雅當場放聲大哭。  0.888889  6.066667         6.0
# 17    60        我精心籌備浪漫的派對，要給女友大大的驚喜。       1.0  6.333333    6.333333
# 18    64       她沉魚落雁傾城傾國，連西施都會讚歎她的美貌。       0.8  5.466667    5.666667
# 19    68        發現老公外遇偷吃，妻子氣不過決定和他談判。       0.0       4.6    5.666667
# 20    68        發現老公外遇偷吃，妻子氣不過決定和他離婚。  0.933333       6.2    6.466667
# 23    76   感謝你在我最低潮時給予我無盡的支持，我內心充滿暖意。       0.0       5.2    5.866667
# 24    76   感謝你在我最低潮時給予我無盡的支持，我內心充滿感激。  0.722222  6.266667         6.4
# 25    77   在森林緩緩漫步並感受微風與陽光，可以為內心帶來暖意。       0.0  4.533333    5.866667
# 26    77   在森林緩緩漫步並感受微風與陽光，可以為內心帶來平靜。    0.8125  6.466667         6.8
# 29    80       這案子手法殘暴，尚未找到殺了老教授的大學生。       0.0  3.133333    4.866667
# 30    80        這案子手法殘暴，尚未找到殺了老教授的兇手。  0.866667       6.2    6.466667
# 34    88         人心險惡，很多敏感又小心眼的人會耍把戲。       0.0  4.933333    5.666667
# 35    88         人心險惡，很多敏感又小心眼的人會耍心機。       1.0       5.8    6.066667
# 36    92  先前某高層貪汙入獄，現今官員應記取這政治界慘痛的教訓。    0.8125  5.666667    6.133333
# 37   100    這位一線女演員憑藉這部劇爆紅，演技也收穫一致好評。  0.933333  5.866667         6.4
# 39   108       公司銷售額不斷攀升，證明他們的策略非常管用。       0.0  5.866667         6.2
# 40   108       公司銷售額不斷攀升，證明他們的策略非常成功。  0.777778  6.266667    6.466667
# 70  1220          寒冬裡因為男友的陪伴，讓我覺得好舒服。       0.0  4.235294    5.764706
# 71  1220          寒冬裡因為男友的陪伴，讓我覺得好溫暖。  0.866667  6.529412    6.647059
# 72  1232   祝福佳偶們像公主與白馬王子婚姻永遠快樂、美滿和長遠。       0.0  4.882353    6.294118
# 73  1232   祝福佳偶們像公主與白馬王子婚姻永遠快樂、美滿和幸福。  0.888889  6.764706    6.764706
# 74  1244       疫情後每一次獲得的演出機會，我都格外地珍惜。  0.933333  6.647059    6.705882
# 75  1248       這個地區治安不好，夜晚走在路上很容易被搶劫。  0.933333  6.588235    6.764706
# 76  1252     阿花作弊被爆打手心，還被叫到走廊上一個人青蛙跳。       0.0  3.647059    5.882353
# 77  1252      阿花作弊被爆打手心，還被叫到走廊上一個人罰站。  0.933333  6.705882    6.705882
# 78  1260  期待去跨年派對狂歡已久，現在即將入場我感到超級想尿尿。       0.0  2.352941    4.705882
# 79  1260   期待去跨年派對狂歡已久，現在即將入場我感到超級興奮。  0.944444  6.705882    6.764706
# 80  1264      父親開的公司連年虧損，使得他得承受很大的責任。       0.0  4.117647    5.705882
# 81  1264      父親開的公司連年虧損，使得他得承受很大的壓力。       1.0  6.764706    6.764706
# 82  1268        教授不斷點頭稱讚，顯然對於研究結果很滿意。       1.0  6.705882    6.705882
# 83  1272      癌症末期的他情緒十分低落，是因為症狀急遽惡化。       1.0  6.470588    6.588235
# 84  1276   這些綠色點點噁爆了，放在陰暗濕冷處太久難怪會有濕氣。       0.0  3.647059    4.823529
# 85  1276    這些綠色點點噁爆了，放在陰暗濕冷處太久難怪會發霉。       1.0  6.411765    6.470588
# 86  1284     男友偷偷從國外回來幫女友慶生，準備給她一個包包。       0.0  4.235294    5.941176
# 87  1284     男友偷偷從國外回來幫女友慶生，準備給她一個驚喜。       1.0  6.764706    6.764706
# 88  1288    經濟不景氣公司大裁員，導致業績不佳的阿偉中年轉行。       0.0  4.588235         6.0
# 89  1288    經濟不景氣公司大裁員，導致業績不佳的阿偉中年失業。       1.0  6.705882    6.764706
# 90  1316       深信丈夫卻發現其外遇偷吃，讓妻子感到被丟棄。       0.0  4.352941    5.882353
# 91  1316       深信丈夫卻發現其外遇偷吃，讓妻子感到被背叛。       0.9  6.705882    6.647059
# 92  1368      沒想到只花五十元買樂透卻中十萬，我真的太幸運。       0.9  6.823529    6.764706
# 93  1416     報告時教授不斷點頭稱讚，顯然對研究成果非常賞識。       0.0  5.882353    6.470588
# 94  1416     報告時教授不斷點頭稱讚，顯然對研究成果非常滿意。      0.95  6.764706    6.764706
#
#    Val. mean Arous. mean
# 3   2.428571    4.285714
# 8   1.785714    4.428571
# 9        3.0    3.714286
# 10       3.0    3.714286
# 13  2.071429    4.428571
# 14  2.071429    4.428571
# 16  2.142857    5.214286
# 17  6.857143    4.285714
# 18  6.928571    3.357143
# 19  2.785714    4.642857
# 20  2.785714    4.642857
# 23  7.071429    4.928571
# 24  7.071429    4.928571
# 25       7.0    3.214286
# 26       7.0    3.214286
# 29  2.428571    3.785714
# 30  2.428571    3.785714
# 34       3.0    4.071429
# 35       3.0    4.071429
# 36       3.0    2.857143
# 37  7.214286    2.428571
# 39  6.857143    2.142857
# 40  6.857143    2.142857
# 70  7.142857    4.714286
# 71  7.142857    4.714286
# 72  7.142857    2.785714
# 73  7.142857    2.785714
# 74  6.857143    4.142857
# 75  2.642857    4.071429
# 76  3.071429         3.5
# 77  3.071429         3.5
# 78       7.0    4.214286
# 79       7.0    4.214286
# 80       3.0         3.5
# 81       3.0         3.5
# 82  7.785714    3.214286
# 83  2.285714    4.285714
# 84  2.357143    4.571429
# 85  2.357143    4.571429
# 86       7.0    3.857143
# 87       7.0    3.857143
# 88  3.142857    3.571429
# 89  3.142857    3.571429
# 90  2.285714    5.142857
# 91  2.285714    5.142857
# 92  7.928571    5.928571
# 93  7.142857         3.5
# 94  7.142857         3.5
# number of Emo_WC sentences = 47
#    Index                     Sentences     Cloze Exp. mean Plaus. mean  \
# 0      6         為了獲取個人私利，他竟不惜放棄家人的名譽。  0.111111  4.666667    5.733333
# 1     10       他總愛設計卑鄙騙局誘人上當，行徑又狡猾又難猜。       0.0  4.333333    5.333333
# 2     10       他總愛設計卑鄙騙局誘人上當，行徑又狡猾又陰險。  0.111111       6.4    6.333333
# 4     14      他哮喘急性發作又不要命地熬夜做工，已經快要缺氧。       0.0       3.6    5.066667
# 5     14      他哮喘急性發作又不要命地熬夜做工，已經快要死去。     0.125       4.2         5.6
# 6     22      最愛的奶奶突然間去世，小明臉上的神情變得很冷淡。       0.0  3.533333    4.733333
# 7     22      最愛的奶奶突然間去世，小明臉上的神情變得很黯然。  0.133333  5.733333         6.4
# 11    38      少年時我成天酗酒吸毒，當時我覺得我的生命好無趣。  0.133333  4.066667    4.933333
# 12    42    罹患極重度憂鬱症後，他常像洩了氣的皮球一樣神色憔悴。  0.133333  5.066667    5.666667
# 15    50     總是第一名又努力的阿邱，在學習方面有非常棒的成就。       0.2  5.933333    6.466667
# 21    70         這棟爬滿藤蔓的凶宅陰森恐怖，滿地都是青苔。       0.0       3.8         5.4
# 22    70         這棟爬滿藤蔓的凶宅陰森恐怖，滿地都是血跡。  0.133333  4.466667         6.0
# 27    78       孩子前腳剛出門就遇車禍身亡，父母倆都哭到天亮。       0.0  3.733333    4.733333
# 28    78       孩子前腳剛出門就遇車禍身亡，父母倆都哭到斷腸。  0.133333  5.533333    6.466667
# 31    82  這間餐廳動作很慢而且上錯菜還反罵客人，服務真的超該改善。       0.0  5.133333    6.133333
# 32    82    這間餐廳動作很慢而且上錯菜還反罵客人，服務真的超差。  0.166667  6.666667         6.6
# 33    86    男友長期垃圾亂堆、髒衣服發臭不想洗，令她感到很噁心。       0.2  6.066667    6.666667
# 38   106     每次吵架都沒有講開，無奈終究令感情和婚姻開始破裂。       0.2       6.0    6.333333
# 41   126      基金會利誘信徒投資吸金，只要不服從就會被迫退出。       0.2  5.533333    5.866667
# 42   138        母親昨晚半夜於醫院病逝，他今天上班非常沮喪。       0.2       5.4    6.133333
# 43   154          他瘋狂打電話來叫我還錢，還不斷對我提醒。       0.0       3.4    4.866667
# 44   154          他瘋狂打電話來叫我還錢，還不斷對我恐嚇。       0.2       5.8    6.133333
# 45   170  明星打開包裹後刺骨地痛心，因為裡面滿滿的都是骯髒的垃圾。       0.2  3.533333    5.533333
# 46   210   極度叛逆的兒子常瘋玩到徹夜未歸，搞得姊姊總是要打電話。       0.0  3.733333    4.933333
# 47   210    極度叛逆的兒子常瘋玩到徹夜未歸，搞得姊姊總是要擔心。       0.2  5.133333    4.666667
# 48   218   他每次沒練好就硬要合體表演，都讓認真練舞的大家看出來。       0.0  3.882353    4.588235
# 49   218    他每次沒練好就硬要合體表演，都讓認真練舞的大家困擾。       0.2  6.294118    6.588235
# 50   222     他借的十萬周轉不幸被詐騙光，絕望下到債主家去解釋。       0.0  3.705882    5.117647
# 51   222     他借的十萬周轉不幸被詐騙光，絕望下到債主家去求情。       0.2  5.647059    6.176471
# 52   438        重考的他看到自己在大學榜單上，終於可以放心。       0.2  6.352941    6.647059
# 53   454         為了爭奪父母巨額遺產，大哥和二哥互相爭吵。       0.2  6.235294    6.588235
# 54   478     張老師用愛的教育，長期深入偏鄉帶給孩子許多的改變。       0.0       5.0    6.470588
# 55   478     張老師用愛的教育，長期深入偏鄉帶給孩子許多的溫暖。       0.2  6.411765    6.705882
# 56   490      她苦練多年總算站上了國際舞台，眼神中充滿著狂熱。       0.0  4.235294    5.764706
# 57   490      她苦練多年總算站上了國際舞台，眼神中充滿著自信。       0.2  6.588235    6.764706
# 58   530       先生遭遇跨國詐騙損失逾千萬，生氣地跟嫌犯對話。       0.0  3.705882    5.117647
# 59   530       先生遭遇跨國詐騙損失逾千萬，生氣地跟嫌犯理論。       0.2  4.882353    5.235294
# 60   538       他不務正業又經常與黑道為伍，現在的工作是保鑣。       0.0  3.294118    4.941176
# 61   538       他不務正業又經常與黑道為伍，現在的工作是討債。  0.133333  5.941176    6.470588
# 62   562        前任分手後還糾纏不放覺得煩，他真是有點狀況。       0.0  3.117647    4.647059
# 63   562        前任分手後還糾纏不放覺得煩，他真是有點問題。     0.125  5.647059    6.294118
# 64   567           終於考完了期中考，同學們心情都很開心。  0.333333  6.470588    6.705882
# 65   570       自從生下畸型胎兒，太太與先生的婚姻只剩下無感。       0.0  3.117647    4.764706
# 66   570       自從生下畸型胎兒，太太與先生的婚姻只剩下照顧。  0.133333  3.411765    5.352941
# 67   578     夫妻倆關係親密無間且深深相愛，是因爲彼此願意經營。       0.0  6.294118    6.588235
# 68   578     夫妻倆關係親密無間且深深相愛，是因爲彼此願意付出。    0.1875  6.529412    6.647059
# 69   586          黑幫老大很想賺大錢，一直慫恿小弟們犯罪。       0.2  5.647059    6.352941
#
#    Val. mean Arous. mean
# 0        2.5    3.357143
# 1   2.142857         4.0
# 2   2.142857         4.0
# 4   2.785714    4.071429
# 5   2.785714    4.071429
# 6   2.428571         5.0
# 7   2.428571         5.0
# 11  2.785714    3.857143
# 12  2.214286    3.714286
# 15  6.928571    2.428571
# 21       3.0    4.785714
# 22       3.0    4.785714
# 27  1.928571    5.214286
# 28  1.928571    5.214286
# 31  2.428571    4.642857
# 32  2.428571    4.642857
# 33  2.142857    4.571429
# 38  2.714286    4.142857
# 41  2.357143    4.142857
# 42  2.285714    5.142857
# 43  2.714286    4.785714
# 44  2.714286    4.785714
# 45       2.5    4.571429
# 46       3.0    3.571429
# 47       3.0    3.571429
# 48  2.857143    4.285714
# 49  2.857143    4.285714
# 50  2.357143    4.142857
# 51  2.357143    4.142857
# 52  6.928571    3.571429
# 53  3.142857         4.0
# 54  7.214286    3.428571
# 55  7.214286    3.428571
# 56  7.285714    4.857143
# 57  7.285714    4.857143
# 58       2.5    4.571429
# 59       2.5    4.571429
# 60  2.928571    2.214286
# 61  2.928571    2.214286
# 62  2.785714    4.928571
# 63  2.785714    4.928571
# 64       7.0    5.071429
# 65  2.785714    3.857143
# 66  2.785714    3.857143
# 67       7.0    4.214286
# 68       7.0    4.214286
# 69  2.928571         3.5
# number of Neu_SC sentences = 82
#     Index                 Sentences     Cloze Exp. mean Plaus. mean Val. mean  \
# 5       9     人與人相處靠的是真心，人與人相遇則是契機。       0.0  4.533333    5.933333  5.357143
# 6       9     人與人相處靠的是真心，人與人相遇則是緣分。       0.8  6.333333    6.733333  5.357143
# 7      17     這一個問題可以問一下設計師，聽聽他的意見。       0.8       6.4    6.666667  5.142857
# 11     29  我上次出國行李安檢卡關，還好後來有順利趕上來了。       0.0  4.933333    5.733333       5.5
# 12     29  我上次出國行李安檢卡關，還好後來有順利趕上飛機。  0.733333  6.333333         6.4       5.5
# ..    ...                       ...       ...       ...         ...       ...
# 148  1365     夜晚時應避免在屋內大聲吵鬧，以免吵到保全。       0.0  2.588235    4.705882  4.571429
# 149  1365     夜晚時應避免在屋內大聲吵鬧，以免吵到鄰居。       0.9  6.823529    6.882353  4.571429
# 150  1376         你不能什麼都想要，這樣實在太貪心。       0.9  6.705882    6.705882  4.357143
# 151  1405   小華明天要考英文，難怪他今天這麼認真在背筆記。       0.0  4.941176    6.470588       5.0
# 152  1405   小華明天要考英文，難怪他今天這麼認真在背單字。       1.0  6.705882    6.764706       5.0
#
#     Arous. mean
# 5      1.785714
# 6      1.785714
# 7      2.357143
# 11     3.285714
# 12     3.285714
# ..          ...
# 148    2.214286
# 149    2.214286
# 150    3.214286
# 151    1.928571
# 152    1.928571
#
# [82 rows x 7 columns]
# number of Neu_WC sentences = 71
#     Index                  Sentences     Cloze Exp. mean Plaus. mean  \
# 0       2    男星在臉書放與辣妹親暱的合照，粉絲們說是姐姐。       0.0  3.533333    5.066667
# 1       2    男星在臉書放與辣妹親暱的合照，粉絲們說是女友。  0.066667       5.0    5.533333
# 2       3  每天上學都是爸爸接送的小明，放學時會在門口等爸爸。       0.4  6.066667    6.066667
# 3       7    這位演員說他拍片的原因，是想要展現出他的理念。       0.0  5.266667    5.866667
# 4       7    這位演員說他拍片的原因，是想要展現出他的魅力。       0.2  5.266667    5.733333
# ..    ...                        ...       ...       ...         ...
# 96    579      我開了一家公司，在財務方面都請下屬來處理。  0.333333  6.352941    6.529412
# 97    583       注重膚質保養的人都會擦這罐，才不會角化。       0.0  4.352941    5.529412
# 98    583       注重膚質保養的人都會擦這罐，才不會乾燥。  0.333333  5.882353    6.470588
# 99    587    這部電影的劇情內容，沒想到是以這樣的方式安排。       0.0  5.705882    6.411765
# 100   587    這部電影的劇情內容，沒想到是以這樣的方式收尾。  0.333333  6.352941    6.588235
#
#     Val. mean Arous. mean
# 0    4.285714    3.142857
# 1    4.285714    3.142857
# 2    5.071429         1.5
# 3    5.785714    2.357143
# 4    5.785714    2.357143
# ..        ...         ...
# 96   4.857143    1.928571
# 97   4.928571         2.5
# 98   4.928571         2.5
# 99   4.642857         3.5
# 100  4.642857         3.5
#
# [71 rows x 7 columns]

# %%
# If we drop singled out sentences
os.chdir('/home/amandalin047/july_ratings/results/1st_round')
df1 = pd.read_excel('1st_all_means.xlsx')
os.chdir('/home/amandalin047/july_ratings/results/2nd_round')
df2 = pd.DataFrame(data=None, columns=pd.read_excel('2nd_all_means.xlsx').columns)

emo_sc, emo_wc = main(df, exp_thresh=8, plaus_thresh=4.5, val_thresh=1.8, condition='Emo', drop=True);
neu_sc, neu_wc = main(df, exp_thresh=8, plaus_thresh=4.5, val_thresh=0.9, condition='Neu', drop=True);
# Out:
# number of Emo_SC frames = 18
#    Index                    Sentences     Cloze Exp. mean Plaus. mean  \
# 9     32      不滿官員暴利欺壓，憤怒的鄉民聚集凱道大聲喊話。       0.0  4.533333         5.2
# 10    32      不滿官員暴利欺壓，憤怒的鄉民聚集凱道大聲抗議。  0.888889  6.266667         6.4
# 13    44      他車禍重傷血肉模糊狀況淒慘，搶救的希望全沒了。       0.0       5.2         5.4
# 14    44       他車禍重傷血肉模糊狀況淒慘，搶救的希望渺茫。  0.866667  5.666667         6.2
# 19    68        發現老公外遇偷吃，妻子氣不過決定和他談判。       0.0       4.6    5.666667
# 20    68        發現老公外遇偷吃，妻子氣不過決定和他離婚。  0.933333       6.2    6.466667
# 23    76   感謝你在我最低潮時給予我無盡的支持，我內心充滿暖意。       0.0       5.2    5.866667
# 24    76   感謝你在我最低潮時給予我無盡的支持，我內心充滿感激。  0.722222  6.266667         6.4
# 25    77   在森林緩緩漫步並感受微風與陽光，可以為內心帶來暖意。       0.0  4.533333    5.866667
# 26    77   在森林緩緩漫步並感受微風與陽光，可以為內心帶來平靜。    0.8125  6.466667         6.8
# 29    80       這案子手法殘暴，尚未找到殺了老教授的大學生。       0.0  3.133333    4.866667
# 30    80        這案子手法殘暴，尚未找到殺了老教授的兇手。  0.866667       6.2    6.466667
# 34    88         人心險惡，很多敏感又小心眼的人會耍把戲。       0.0  4.933333    5.666667
# 35    88         人心險惡，很多敏感又小心眼的人會耍心機。       1.0       5.8    6.066667
# 39   108       公司銷售額不斷攀升，證明他們的策略非常管用。       0.0  5.866667         6.2
# 40   108       公司銷售額不斷攀升，證明他們的策略非常成功。  0.777778  6.266667    6.466667
# 70  1220          寒冬裡因為男友的陪伴，讓我覺得好舒服。       0.0  4.235294    5.764706
# 71  1220          寒冬裡因為男友的陪伴，讓我覺得好溫暖。  0.866667  6.529412    6.647059
# 72  1232   祝福佳偶們像公主與白馬王子婚姻永遠快樂、美滿和長遠。       0.0  4.882353    6.294118
# 73  1232   祝福佳偶們像公主與白馬王子婚姻永遠快樂、美滿和幸福。  0.888889  6.764706    6.764706
# 76  1252     阿花作弊被爆打手心，還被叫到走廊上一個人青蛙跳。       0.0  3.647059    5.882353
# 77  1252      阿花作弊被爆打手心，還被叫到走廊上一個人罰站。  0.933333  6.705882    6.705882
# 78  1260  期待去跨年派對狂歡已久，現在即將入場我感到超級想尿尿。       0.0  2.352941    4.705882
# 79  1260   期待去跨年派對狂歡已久，現在即將入場我感到超級興奮。  0.944444  6.705882    6.764706
# 80  1264      父親開的公司連年虧損，使得他得承受很大的責任。       0.0  4.117647    5.705882
# 81  1264      父親開的公司連年虧損，使得他得承受很大的壓力。       1.0  6.764706    6.764706
# 84  1276   這些綠色點點噁爆了，放在陰暗濕冷處太久難怪會有濕氣。       0.0  3.647059    4.823529
# 85  1276    這些綠色點點噁爆了，放在陰暗濕冷處太久難怪會發霉。       1.0  6.411765    6.470588
# 86  1284     男友偷偷從國外回來幫女友慶生，準備給她一個包包。       0.0  4.235294    5.941176
# 87  1284     男友偷偷從國外回來幫女友慶生，準備給她一個驚喜。       1.0  6.764706    6.764706
# 88  1288    經濟不景氣公司大裁員，導致業績不佳的阿偉中年轉行。       0.0  4.588235         6.0
# 89  1288    經濟不景氣公司大裁員，導致業績不佳的阿偉中年失業。       1.0  6.705882    6.764706
# 90  1316       深信丈夫卻發現其外遇偷吃，讓妻子感到被丟棄。       0.0  4.352941    5.882353
# 91  1316       深信丈夫卻發現其外遇偷吃，讓妻子感到被背叛。       0.9  6.705882    6.647059
# 93  1416     報告時教授不斷點頭稱讚，顯然對研究成果非常賞識。       0.0  5.882353    6.470588
# 94  1416     報告時教授不斷點頭稱讚，顯然對研究成果非常滿意。      0.95  6.764706    6.764706
#
#    Val. mean Arous. mean
# 9        3.0    3.714286
# 10       3.0    3.714286
# 13  2.071429    4.428571
# 14  2.071429    4.428571
# 19  2.785714    4.642857
# 20  2.785714    4.642857
# 23  7.071429    4.928571
# 24  7.071429    4.928571
# 25       7.0    3.214286
# 26       7.0    3.214286
# 29  2.428571    3.785714
# 30  2.428571    3.785714
# 34       3.0    4.071429
# 35       3.0    4.071429
# 39  6.857143    2.142857
# 40  6.857143    2.142857
# 70  7.142857    4.714286
# 71  7.142857    4.714286
# 72  7.142857    2.785714
# 73  7.142857    2.785714
# 76  3.071429         3.5
# 77  3.071429         3.5
# 78       7.0    4.214286
# 79       7.0    4.214286
# 80       3.0         3.5
# 81       3.0         3.5
# 84  2.357143    4.571429
# 85  2.357143    4.571429
# 86       7.0    3.857143
# 87       7.0    3.857143
# 88  3.142857    3.571429
# 89  3.142857    3.571429
# 90  2.285714    5.142857
# 91  2.285714    5.142857
# 93  7.142857         3.5
# 94  7.142857         3.5
# number of Emo_WC frames = 17
#    Index                     Sentences     Cloze Exp. mean Plaus. mean  \
# 1     10       他總愛設計卑鄙騙局誘人上當，行徑又狡猾又難猜。       0.0  4.333333    5.333333
# 2     10       他總愛設計卑鄙騙局誘人上當，行徑又狡猾又陰險。  0.111111       6.4    6.333333
# 4     14      他哮喘急性發作又不要命地熬夜做工，已經快要缺氧。       0.0       3.6    5.066667
# 5     14      他哮喘急性發作又不要命地熬夜做工，已經快要死去。     0.125       4.2         5.6
# 6     22      最愛的奶奶突然間去世，小明臉上的神情變得很冷淡。       0.0  3.533333    4.733333
# 7     22      最愛的奶奶突然間去世，小明臉上的神情變得很黯然。  0.133333  5.733333         6.4
# 21    70         這棟爬滿藤蔓的凶宅陰森恐怖，滿地都是青苔。       0.0       3.8         5.4
# 22    70         這棟爬滿藤蔓的凶宅陰森恐怖，滿地都是血跡。  0.133333  4.466667         6.0
# 27    78       孩子前腳剛出門就遇車禍身亡，父母倆都哭到天亮。       0.0  3.733333    4.733333
# 28    78       孩子前腳剛出門就遇車禍身亡，父母倆都哭到斷腸。  0.133333  5.533333    6.466667
# 31    82  這間餐廳動作很慢而且上錯菜還反罵客人，服務真的超該改善。       0.0  5.133333    6.133333
# 32    82    這間餐廳動作很慢而且上錯菜還反罵客人，服務真的超差。  0.166667  6.666667         6.6
# 43   154          他瘋狂打電話來叫我還錢，還不斷對我提醒。       0.0       3.4    4.866667
# 44   154          他瘋狂打電話來叫我還錢，還不斷對我恐嚇。       0.2       5.8    6.133333
# 46   210   極度叛逆的兒子常瘋玩到徹夜未歸，搞得姊姊總是要打電話。       0.0  3.733333    4.933333
# 47   210    極度叛逆的兒子常瘋玩到徹夜未歸，搞得姊姊總是要擔心。       0.2  5.133333    4.666667
# 48   218   他每次沒練好就硬要合體表演，都讓認真練舞的大家看出來。       0.0  3.882353    4.588235
# 49   218    他每次沒練好就硬要合體表演，都讓認真練舞的大家困擾。       0.2  6.294118    6.588235
# 50   222     他借的十萬周轉不幸被詐騙光，絕望下到債主家去解釋。       0.0  3.705882    5.117647
# 51   222     他借的十萬周轉不幸被詐騙光，絕望下到債主家去求情。       0.2  5.647059    6.176471
# 54   478     張老師用愛的教育，長期深入偏鄉帶給孩子許多的改變。       0.0       5.0    6.470588
# 55   478     張老師用愛的教育，長期深入偏鄉帶給孩子許多的溫暖。       0.2  6.411765    6.705882
# 56   490      她苦練多年總算站上了國際舞台，眼神中充滿著狂熱。       0.0  4.235294    5.764706
# 57   490      她苦練多年總算站上了國際舞台，眼神中充滿著自信。       0.2  6.588235    6.764706
# 58   530       先生遭遇跨國詐騙損失逾千萬，生氣地跟嫌犯對話。       0.0  3.705882    5.117647
# 59   530       先生遭遇跨國詐騙損失逾千萬，生氣地跟嫌犯理論。       0.2  4.882353    5.235294
# 60   538       他不務正業又經常與黑道為伍，現在的工作是保鑣。       0.0  3.294118    4.941176
# 61   538       他不務正業又經常與黑道為伍，現在的工作是討債。  0.133333  5.941176    6.470588
# 62   562        前任分手後還糾纏不放覺得煩，他真是有點狀況。       0.0  3.117647    4.647059
# 63   562        前任分手後還糾纏不放覺得煩，他真是有點問題。     0.125  5.647059    6.294118
# 65   570       自從生下畸型胎兒，太太與先生的婚姻只剩下無感。       0.0  3.117647    4.764706
# 66   570       自從生下畸型胎兒，太太與先生的婚姻只剩下照顧。  0.133333  3.411765    5.352941
# 67   578     夫妻倆關係親密無間且深深相愛，是因爲彼此願意經營。       0.0  6.294118    6.588235
# 68   578     夫妻倆關係親密無間且深深相愛，是因爲彼此願意付出。    0.1875  6.529412    6.647059
#
#    Val. mean Arous. mean
# 1   2.142857         4.0
# 2   2.142857         4.0
# 4   2.785714    4.071429
# 5   2.785714    4.071429
# 6   2.428571         5.0
# 7   2.428571         5.0
# 21       3.0    4.785714
# 22       3.0    4.785714
# 27  1.928571    5.214286
# 28  1.928571    5.214286
# 31  2.428571    4.642857
# 32  2.428571    4.642857
# 43  2.714286    4.785714
# 44  2.714286    4.785714
# 46       3.0    3.571429
# 47       3.0    3.571429
# 48  2.857143    4.285714
# 49  2.857143    4.285714
# 50  2.357143    4.142857
# 51  2.357143    4.142857
# 54  7.214286    3.428571
# 55  7.214286    3.428571
# 56  7.285714    4.857143
# 57  7.285714    4.857143
# 58       2.5    4.571429
# 59       2.5    4.571429
# 60  2.928571    2.214286
# 61  2.928571    2.214286
# 62  2.785714    4.928571
# 63  2.785714    4.928571
# 65  2.785714    3.857143
# 66  2.785714    3.857143
# 67       7.0    4.214286
# 68       7.0    4.214286
# number of Neu_SC frames = 33
#     Index                 Sentences     Cloze Exp. mean Plaus. mean Val. mean  \
# 5       9     人與人相處靠的是真心，人與人相遇則是契機。       0.0  4.533333    5.933333  5.357143
# 6       9     人與人相處靠的是真心，人與人相遇則是緣分。       0.8  6.333333    6.733333  5.357143
# 11     29  我上次出國行李安檢卡關，還好後來有順利趕上來了。       0.0  4.933333    5.733333       5.5
# 12     29  我上次出國行李安檢卡關，還好後來有順利趕上飛機。  0.733333  6.333333         6.4       5.5
# 13     33      他最近有點低潮，看到他可以給他加油喊話。       0.0  5.333333         5.6  5.142857
# ..    ...                       ...       ...       ...         ...       ...
# 147  1357     小明放學後都會搭捷運，再到站牌這裡等公車。       0.9  6.470588    6.470588  5.071429
# 148  1365     夜晚時應避免在屋內大聲吵鬧，以免吵到保全。       0.0  2.588235    4.705882  4.571429
# 149  1365     夜晚時應避免在屋內大聲吵鬧，以免吵到鄰居。       0.9  6.823529    6.882353  4.571429
# 151  1405   小華明天要考英文，難怪他今天這麼認真在背筆記。       0.0  4.941176    6.470588       5.0
# 152  1405   小華明天要考英文，難怪他今天這麼認真在背單字。       1.0  6.705882    6.764706       5.0
#
#     Arous. mean
# 5      1.785714
# 6      1.785714
# 11     3.285714
# 12     3.285714
# 13     3.142857
# ..          ...
# 147    1.571429
# 148    2.214286
# 149    2.214286
# 151    1.928571
# 152    1.928571
#
# [67 rows x 7 columns]
# number of Neu_WC frames = 23
#     Index                   Sentences     Cloze Exp. mean Plaus. mean  \
# 0       2     男星在臉書放與辣妹親暱的合照，粉絲們說是姐姐。       0.0  3.533333    5.066667
# 1       2     男星在臉書放與辣妹親暱的合照，粉絲們說是女友。  0.066667       5.0    5.533333
# 3       7     這位演員說他拍片的原因，是想要展現出他的理念。       0.0  5.266667    5.866667
# 4       7     這位演員說他拍片的原因，是想要展現出他的魅力。       0.2  5.266667    5.733333
# 9      27      今天的課程，主要是為了要讓學生瞭解這個篇章。       0.0  4.733333    6.066667
# 10     27      今天的課程，主要是為了要讓學生瞭解這個概念。  0.266667  6.533333         6.8
# 32     71        今早和家人出外踏青，看到山上有許多青苔。       0.0  3.266667    5.533333
# 33     71        今早和家人出外踏青，看到山上有許多遊客。       0.2  5.333333         6.2
# 34     79        他擔任公園清掃人員，打掃完已經快要天亮。       0.0  4.533333    4.933333
# 35     79        他擔任公園清掃人員，打掃完已經快要中午。  0.266667  4.466667    5.866667
# 41     90   他吃下許多用楓糖跟糖霜製作出的美食，滋味很不一樣。       0.0       4.2    5.066667
# 42     90    他吃下許多用楓糖跟糖霜製作出的美食，滋味很甜膩。    0.1875  4.466667         4.8
# 55    158    青澀初戀很可惜沒走到最後，每每想起總令我放不下。       0.0  5.333333         5.2
# 56    158     青澀初戀很可惜沒走到最後，每每想起總令我惋惜。       0.2  6.333333         6.4
# 62    211   他有一個特殊的習慣，就是會在凌晨三點的時候打電話。       0.0  4.266667    6.133333
# 63    211    他有一個特殊的習慣，就是會在凌晨三點的時候起床。  0.266667       4.8         6.0
# 65    219   這幅畫作使用很細微的色差來表達，有點不太好看出來。       0.0  6.235294    6.411765
# 66    219    這幅畫作使用很細微的色差來表達，有點不太好理解。     0.375  4.411765    5.588235
# 67    223  為了了解這個商業糾紛案件，明天我會請相關人士來解釋。       0.0  4.882353    6.117647
# 68    223  為了了解這個商業糾紛案件，明天我會請相關人士來處理。  0.277778  6.470588    6.529412
# 69    227      很多朝代歷史都非常相似，常常上演一樣的迴圈。       0.0  4.588235         6.0
# 70    227      很多朝代歷史都非常相似，常常上演一樣的劇情。  0.266667  5.705882    6.058824
# 72    234      中年時我到垃圾焚化廠工作，那裡的環境很老舊。       0.0  4.588235    5.941176
# 73    234      中年時我到垃圾焚化廠工作，那裡的環境很骯髒。       0.2  6.235294    6.588235
# 74    235         我剛搬到鄉下來，發現這裡的環境很老舊。       0.0  5.764706    6.470588
# 75    235         我剛搬到鄉下來，發現這裡的環境很清幽。  0.277778  6.529412    6.764706
# 76    371         這個企劃案，將交由張小姐做全權的安排。       0.0  6.117647    6.529412
# 77    371         這個企劃案，將交由張小姐做全權的處理。  0.333333  6.470588    6.764706
# 78    447      他是個有主見的人，對於事情有自己的一套規矩。       0.0  6.294118    6.705882
# 79    447      他是個有主見的人，對於事情有自己的一套見解。       0.2  6.705882    6.764706
# 80    455        這次的期末分組報告，我們五個會一起聯手。       0.0  2.823529    5.117647
# 81    455        這次的期末分組報告，我們五個會一起合作。  0.266667  6.588235    6.647059
# 82    479      政府已擬定新的配套措施，年底前會有更多改變。       0.0  4.764706    5.411765
# 83    479      政府已擬定新的配套措施，年底前會有更多消息。  0.133333  6.294118    6.647059
# 84    519    牆壁上的老式鐘擺有特定的節奏，擺動看起來蠻正常。       0.0  3.176471    4.647059
# 85    519    牆壁上的老式鐘擺有特定的節奏，擺動看起來蠻規律。  0.266667       6.0    6.470588
# 86    531       上完卡內基的人際課程後，我開始跟同事對話。       0.0  4.882353    6.058824
# 87    531       上完卡內基的人際課程後，我開始跟同事交流。       0.2  6.176471    6.411765
# 91    551         十分鐘後要考試了，老師請同學避免睡著。       0.0  3.764706    5.294118
# 92    551         十分鐘後要考試了，老師請同學避免交談。  0.266667  6.470588    6.764706
# 93    563     新聞報導說中颱即將來襲，沒想到最後是這個狀況。       0.0  4.352941    6.058824
# 94    563     新聞報導說中颱即將來襲，沒想到最後是這個烏龍。  0.266667  3.764706    5.235294
# 97    583        注重膚質保養的人都會擦這罐，才不會角化。       0.0  4.352941    5.529412
# 98    583        注重膚質保養的人都會擦這罐，才不會乾燥。  0.333333  5.882353    6.470588
# 99    587     這部電影的劇情內容，沒想到是以這樣的方式安排。       0.0  5.705882    6.411765
# 100   587     這部電影的劇情內容，沒想到是以這樣的方式收尾。  0.333333  6.352941    6.588235
#
#     Val. mean Arous. mean
# 0    4.285714    3.142857
# 1    4.285714    3.142857
# 3    5.785714    2.357143
# 4    5.785714    2.357143
# 9    5.071429    1.571429
# 10   5.071429    1.571429
# 32   5.642857    1.857143
# 33   5.642857    1.857143
# 34        5.0         2.5
# 35        5.0         2.5
# 41   5.714286    3.142857
# 42   5.714286    3.142857
# 55   4.357143    3.571429
# 56   4.357143    3.571429
# 62   4.785714    2.357143
# 63   4.785714    2.357143
# 65   4.714286    1.928571
# 66   4.714286    1.928571
# 67   4.928571         2.0
# 68   4.928571         2.0
# 69        4.5    2.214286
# 70        4.5    2.214286
# 72   4.142857         3.0
# 73   4.142857         3.0
# 74        5.0    1.714286
# 75        5.0    1.714286
# 76   4.928571    1.714286
# 77   4.928571    1.714286
# 78   5.714286    1.857143
# 79   5.714286    1.857143
# 80        5.0    2.071429
# 81        5.0    2.071429
# 82   5.285714    1.928571
# 83   5.285714    1.928571
# 84   5.714286    1.928571
# 85   5.714286    1.928571
# 86   5.571429    2.571429
# 87   5.571429    2.571429
# 91   5.071429    2.071429
# 92   5.071429    2.071429
# 93   5.214286    3.285714
# 94   5.214286    3.285714
# 97   4.928571         2.5
# 98   4.928571         2.5
# 99   4.642857         3.5
# 100  4.642857         3.5
